# %% [markdown]
# <a href="https://colab.research.google.com/github/Shaurya-XD/Data_Analysis_Anime/blob/main/Seaborn%26MatPlotLib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 5, 11)
y = x**2
plt.plot(x, y)
plt.title("Hello")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
# Out:
# Text(0, 0.5, 'y-axis')

# %%
plt.subplot(2,2,1)
plt.plot(x,y)
plt.subplot(2,2,2)
plt.plot(y,x)
plt.subplot(2,2,3)
plt.plot(x,x)
plt.subplot(2,2,4)
plt.plot(y,y)

# %%
fig = plt.figure()
axis1 = fig.add_axes([0.1,0.1,0.8,0.8])
axis1.plot(x,y)
plt.savefig("plot1.png")
axis2 = fig.add_axes([1,0.3,0.5,0.5])
axis2.plot(y,x)

# %%
plt.scatter(x,y)

# %%
plt.hist(y)
# Out:
# (array([4., 1., 1., 1., 1., 0., 1., 0., 1., 1.]),
#  array([ 0. ,  2.5,  5. ,  7.5, 10. , 12.5, 15. , 17.5, 20. , 22.5, 25. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fe9a273ac30>,
#   <matplotlib.lines.Line2D at 0x7fe9a273af60>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fe9a273b200>,
#   <matplotlib.lines.Line2D at 0x7fe9a273b350>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fe9a273a9c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fe9a273b590>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fe9a273b860>],
#  'means': []}

# %%
import matplotlib.image as mpimg
img = mpimg.imread('CR7.png')
plt.imshow(img)

# %%
crop_img = img[200:,250:1550]
plt.imshow(crop_img)

# %%
import seaborn as sns

# %%
df1 = sns.load_dataset('tips')
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df1['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5])

# %%
plt.subplot(1,2,1)
sns.histplot(df1['total_bill'], bins=20, kde = True)
plt.subplot(1,2,2)
sns.histplot(df1['tip'], bins=20, kde = True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.jointplot(x='total_bill', y='tip', data = df1, kind='scatter')

# %%
sns.jointplot(x='total_bill', y='tip', data = df1, kind='kde')

# %%
sns.jointplot(x='total_bill', y='tip', data = df1, kind='reg')

# %%
sns.pairplot(df1, hue='size', palette='rainbow')

# %%
sns.rugplot(df1)
# Out:
# <Axes: >

# %%
sns.countplot(x = df1['sex'], hue = df1['smoker'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.barplot(x = df1['sex'], y = df1['total_bill'])
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x = df1['sex'], y = df1['tip'], estimator=np.sum)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(x = 'tip', y = 'day', data = df1)
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %%
sns.violinplot(x = 'day', y='total_bill', data = df1)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x = 'day', y='total_bill', data=df1)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x = 'day', y='total_bill', data=df1)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x = 'tip', y='day', data=df1)
sns.swarmplot(x = 'tip', y='day', data=df1)
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 9.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 10.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='tip', ylabel='day'>
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 8.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
